# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Dense
from tensorflow.keras.layers import AvgPool2D, GlobalAveragePooling2D, MaxPool2D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import ReLU, concatenate
import tensorflow.keras.backend as K

# %%
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

#split the data
num_train = 2000
train_images = train_images[:num_train]
train_labels = train_labels[:num_train]

num_test = 450
test_images = test_images[:num_test]
test_labels = test_labels[:num_test]

# %%
CLASS_NAMES= ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
validation_images, validation_labels = train_images[:500], train_labels[:500]
train_images, train_labels = train_images[500:], train_labels[500:]

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_images, train_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_images, test_labels))
validation_ds = tf.data.Dataset.from_tensor_slices((validation_images, validation_labels))

# %%
plt.figure(figsize=(20,20))
for i, (image, label) in enumerate(train_ds.take(5)):
    ax = plt.subplot(5,5,i+1)
    plt.imshow(image)
    plt.title(CLASS_NAMES[label.numpy()[0]])
    plt.axis('off')

# %%
def process_images(image, label):
    # Normalize images to have a mean of 0 and standard deviation of 1
    image = tf.image.per_image_standardization(image)
    # Resize images from 32x32 to 277x277
    image = tf.image.resize(image, (227,227))
    return image, label

# %%
train_ds_size = tf.data.experimental.cardinality(train_ds).numpy()
test_ds_size = tf.data.experimental.cardinality(test_ds).numpy()
validation_ds_size = tf.data.experimental.cardinality(validation_ds).numpy()
print("Training data size:", train_ds_size)
print("Test data size:", test_ds_size)
print("Validation data size:", validation_ds_size)
# Out:
# Training data size: 1500
# Test data size: 450
# Validation data size: 500

# %%
train_ds = (train_ds
                  .map(process_images)
                  .shuffle(buffer_size=train_ds_size)
                  .batch(batch_size=32, drop_remainder=True))
test_ds = (test_ds
                  .map(process_images)
                  .shuffle(buffer_size=train_ds_size)
                  .batch(batch_size=32, drop_remainder=True))
validation_ds = (validation_ds
                  .map(process_images)
                  .shuffle(buffer_size=train_ds_size)
                  .batch(batch_size=32, drop_remainder=True))

# %%
# Creating Densenet121
def densenet(input_shape, n_classes, filters = 32):
    
    #batch norm + relu + conv
    def bn_rl_conv(x,filters,kernel=1,strides=1):
        
        x = BatchNormalization()(x)
        x = ReLU()(x)
        x = Conv2D(filters, kernel, strides=strides,padding = 'same')(x)
        return x
    
    def dense_block(x, repetition):
        
        for _ in range(repetition):
            y = bn_rl_conv(x, 4*filters)
            y = bn_rl_conv(y, filters, 3)
            x = concatenate([y,x])
        return x
        
    def transition_layer(x):
        
        x = bn_rl_conv(x, K.int_shape(x)[-1] //2 )
        x = AvgPool2D(2, strides = 2, padding = 'same')(x)
        return x
    
    input = Input (input_shape)
    x = Conv2D(64, 7, strides = 2, padding = 'same')(input)
    x = MaxPool2D(3, strides = 2, padding = 'same')(x)
    
    for repetition in [6,12,24,16]:
        
        d = dense_block(x, repetition)
        x = transition_layer(d)
    x = GlobalAveragePooling2D()(d)
    output = Dense(n_classes, activation = 'softmax')(x)
    
    model = Model(input, output)
    return model
input_shape = 227, 227, 3
n_classes = 10
model = densenet(input_shape,n_classes)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 227, 227, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 114, 114, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 57, 57, 64)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 57, 57, 64)  256         ['max_pooling2d[0][0]']
#  alization)
#
#  re_lu (ReLU)                   (None, 57, 57, 64)   0           ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 57, 57, 128)  8320        ['re_lu[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_1[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 57, 57, 128)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 57, 57, 32)   36896       ['re_lu_1[0][0]']
#
#  concatenate (Concatenate)      (None, 57, 57, 96)   0           ['conv2d_2[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 57, 57, 96)  384         ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 57, 57, 96)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 57, 57, 128)  12416       ['re_lu_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 57, 57, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 57, 57, 32)   36896       ['re_lu_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 57, 57, 128)  0           ['conv2d_4[0][0]',
#                                                                   'concatenate[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 57, 57, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 57, 57, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 57, 57, 128)  16512       ['re_lu_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 57, 57, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 57, 57, 32)   36896       ['re_lu_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 57, 57, 160)  0           ['conv2d_6[0][0]',
#                                                                   'concatenate_1[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 57, 57, 160)  640        ['concatenate_2[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 57, 57, 160)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 57, 57, 128)  20608       ['re_lu_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 57, 57, 128)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 57, 57, 32)   36896       ['re_lu_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 57, 57, 192)  0           ['conv2d_8[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 57, 57, 192)  768        ['concatenate_3[0][0]']
#  rmalization)
#
#  re_lu_8 (ReLU)                 (None, 57, 57, 192)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 57, 57, 128)  24704       ['re_lu_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 57, 57, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  re_lu_9 (ReLU)                 (None, 57, 57, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 57, 57, 32)   36896       ['re_lu_9[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 57, 57, 224)  0           ['conv2d_10[0][0]',
#                                                                   'concatenate_3[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 57, 57, 224)  896        ['concatenate_4[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 57, 57, 224)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 57, 57, 128)  28800       ['re_lu_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 57, 57, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 57, 57, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 57, 57, 32)   36896       ['re_lu_11[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 57, 57, 256)  0           ['conv2d_12[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 57, 57, 256)  1024       ['concatenate_5[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 57, 57, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 57, 57, 128)  32896       ['re_lu_12[0][0]']
#
#  average_pooling2d (AveragePool  (None, 29, 29, 128)  0          ['conv2d_13[0][0]']
#  ing2D)
#
#  batch_normalization_13 (BatchN  (None, 29, 29, 128)  512        ['average_pooling2d[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 29, 29, 128)  16512       ['re_lu_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 29, 29, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_14[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 29, 29, 160)  0           ['conv2d_15[0][0]',
#                                                                   'average_pooling2d[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 29, 29, 160)  640        ['concatenate_6[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 29, 29, 160)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 29, 29, 128)  20608       ['re_lu_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 29, 29, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_16[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 29, 29, 192)  0           ['conv2d_17[0][0]',
#                                                                   'concatenate_6[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 29, 29, 192)  768        ['concatenate_7[0][0]']
#  ormalization)
#
#  re_lu_17 (ReLU)                (None, 29, 29, 192)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 29, 29, 128)  24704       ['re_lu_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 29, 29, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_18 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_18[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 29, 29, 224)  0           ['conv2d_19[0][0]',
#                                                                   'concatenate_7[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 29, 29, 224)  896        ['concatenate_8[0][0]']
#  ormalization)
#
#  re_lu_19 (ReLU)                (None, 29, 29, 224)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 29, 29, 128)  28800       ['re_lu_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 29, 29, 128)  512        ['conv2d_20[0][0]']
#  ormalization)
#
#  re_lu_20 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_20[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 29, 29, 256)  0           ['conv2d_21[0][0]',
#                                                                   'concatenate_8[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 29, 29, 256)  1024       ['concatenate_9[0][0]']
#  ormalization)
#
#  re_lu_21 (ReLU)                (None, 29, 29, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 29, 29, 128)  32896       ['re_lu_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 29, 29, 128)  512        ['conv2d_22[0][0]']
#  ormalization)
#
#  re_lu_22 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_22[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 29, 29, 288)  0           ['conv2d_23[0][0]',
#                                                                   'concatenate_9[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 29, 29, 288)  1152       ['concatenate_10[0][0]']
#  ormalization)
#
#  re_lu_23 (ReLU)                (None, 29, 29, 288)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 29, 29, 128)  36992       ['re_lu_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 29, 29, 128)  512        ['conv2d_24[0][0]']
#  ormalization)
#
#  re_lu_24 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_24[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 29, 29, 320)  0           ['conv2d_25[0][0]',
#                                                                   'concatenate_10[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 29, 29, 320)  1280       ['concatenate_11[0][0]']
#  ormalization)
#
#  re_lu_25 (ReLU)                (None, 29, 29, 320)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 29, 29, 128)  41088       ['re_lu_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 29, 29, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  re_lu_26 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_26[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 29, 29, 352)  0           ['conv2d_27[0][0]',
#                                                                   'concatenate_11[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 29, 29, 352)  1408       ['concatenate_12[0][0]']
#  ormalization)
#
#  re_lu_27 (ReLU)                (None, 29, 29, 352)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 29, 29, 128)  45184       ['re_lu_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 29, 29, 128)  512        ['conv2d_28[0][0]']
#  ormalization)
#
#  re_lu_28 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_28[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 29, 29, 384)  0           ['conv2d_29[0][0]',
#                                                                   'concatenate_12[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 29, 29, 384)  1536       ['concatenate_13[0][0]']
#  ormalization)
#
#  re_lu_29 (ReLU)                (None, 29, 29, 384)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 29, 29, 128)  49280       ['re_lu_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 29, 29, 128)  512        ['conv2d_30[0][0]']
#  ormalization)
#
#  re_lu_30 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_30[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 29, 29, 416)  0           ['conv2d_31[0][0]',
#                                                                   'concatenate_13[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 29, 29, 416)  1664       ['concatenate_14[0][0]']
#  ormalization)
#
#  re_lu_31 (ReLU)                (None, 29, 29, 416)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 29, 29, 128)  53376       ['re_lu_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 29, 29, 128)  512        ['conv2d_32[0][0]']
#  ormalization)
#
#  re_lu_32 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_32[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 29, 29, 448)  0           ['conv2d_33[0][0]',
#                                                                   'concatenate_14[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 29, 29, 448)  1792       ['concatenate_15[0][0]']
#  ormalization)
#
#  re_lu_33 (ReLU)                (None, 29, 29, 448)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 29, 29, 128)  57472       ['re_lu_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 29, 29, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  re_lu_34 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_34[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 29, 29, 480)  0           ['conv2d_35[0][0]',
#                                                                   'concatenate_15[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 29, 29, 480)  1920       ['concatenate_16[0][0]']
#  ormalization)
#
#  re_lu_35 (ReLU)                (None, 29, 29, 480)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 29, 29, 128)  61568       ['re_lu_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 29, 29, 128)  512        ['conv2d_36[0][0]']
#  ormalization)
#
#  re_lu_36 (ReLU)                (None, 29, 29, 128)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 29, 29, 32)   36896       ['re_lu_36[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 29, 29, 512)  0           ['conv2d_37[0][0]',
#                                                                   'concatenate_16[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 29, 29, 512)  2048       ['concatenate_17[0][0]']
#  ormalization)
#
#  re_lu_37 (ReLU)                (None, 29, 29, 512)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 29, 29, 256)  131328      ['re_lu_37[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 15, 15, 256)  0          ['conv2d_38[0][0]']
#  oling2D)
#
#  batch_normalization_38 (BatchN  (None, 15, 15, 256)  1024       ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  re_lu_38 (ReLU)                (None, 15, 15, 256)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 15, 15, 128)  32896       ['re_lu_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 15, 15, 128)  512        ['conv2d_39[0][0]']
#  ormalization)
#
#  re_lu_39 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_39[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 15, 15, 288)  0           ['conv2d_40[0][0]',
#                                                                   'average_pooling2d_1[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 15, 15, 288)  1152       ['concatenate_18[0][0]']
#  ormalization)
#
#  re_lu_40 (ReLU)                (None, 15, 15, 288)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 15, 15, 128)  36992       ['re_lu_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 15, 15, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  re_lu_41 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_41[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 15, 15, 320)  0           ['conv2d_42[0][0]',
#                                                                   'concatenate_18[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 15, 15, 320)  1280       ['concatenate_19[0][0]']
#  ormalization)
#
#  re_lu_42 (ReLU)                (None, 15, 15, 320)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 15, 15, 128)  41088       ['re_lu_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 15, 15, 128)  512        ['conv2d_43[0][0]']
#  ormalization)
#
#  re_lu_43 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_43[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 15, 15, 352)  0           ['conv2d_44[0][0]',
#                                                                   'concatenate_19[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 15, 15, 352)  1408       ['concatenate_20[0][0]']
#  ormalization)
#
#  re_lu_44 (ReLU)                (None, 15, 15, 352)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 15, 15, 128)  45184       ['re_lu_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 15, 15, 128)  512        ['conv2d_45[0][0]']
#  ormalization)
#
#  re_lu_45 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_45[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 15, 15, 384)  0           ['conv2d_46[0][0]',
#                                                                   'concatenate_20[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 15, 15, 384)  1536       ['concatenate_21[0][0]']
#  ormalization)
#
#  re_lu_46 (ReLU)                (None, 15, 15, 384)  0           ['batch_normalization_46[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 15, 15, 128)  49280       ['re_lu_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 15, 15, 128)  512        ['conv2d_47[0][0]']
#  ormalization)
#
#  re_lu_47 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_47[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 15, 15, 416)  0           ['conv2d_48[0][0]',
#                                                                   'concatenate_21[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 15, 15, 416)  1664       ['concatenate_22[0][0]']
#  ormalization)
#
#  re_lu_48 (ReLU)                (None, 15, 15, 416)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 15, 15, 128)  53376       ['re_lu_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 15, 15, 128)  512        ['conv2d_49[0][0]']
#  ormalization)
#
#  re_lu_49 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_49[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 15, 15, 448)  0           ['conv2d_50[0][0]',
#                                                                   'concatenate_22[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 15, 15, 448)  1792       ['concatenate_23[0][0]']
#  ormalization)
#
#  re_lu_50 (ReLU)                (None, 15, 15, 448)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 15, 15, 128)  57472       ['re_lu_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 15, 15, 128)  512        ['conv2d_51[0][0]']
#  ormalization)
#
#  re_lu_51 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_51[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_51[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 15, 15, 480)  0           ['conv2d_52[0][0]',
#                                                                   'concatenate_23[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 15, 15, 480)  1920       ['concatenate_24[0][0]']
#  ormalization)
#
#  re_lu_52 (ReLU)                (None, 15, 15, 480)  0           ['batch_normalization_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 15, 15, 128)  61568       ['re_lu_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 15, 15, 128)  512        ['conv2d_53[0][0]']
#  ormalization)
#
#  re_lu_53 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_53[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 15, 15, 32)   36896       ['re_lu_53[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 15, 15, 512)  0           ['conv2d_54[0][0]',
#                                                                   'concatenate_24[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 15, 15, 512)  2048       ['concatenate_25[0][0]']
#  ormalization)
#
#  re_lu_54 (ReLU)                (None, 15, 15, 512)  0           ['batch_normalization_54[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 15, 15, 128)  65664       ['re_lu_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 15, 15, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  re_lu_55 (ReLU)                (None, 15, 15, 128)  0           ['batch_normalization_55[0][0]']
# ...
#  Normalization)
#
#  re_lu_101 (ReLU)               (None, 8, 8, 736)    0           ['batch_normalization_101[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 8, 8, 128)    94336       ['re_lu_101[0][0]']
#
#  batch_normalization_102 (Batch  (None, 8, 8, 128)   512         ['conv2d_102[0][0]']
#  Normalization)
#
#  re_lu_102 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_102[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_102[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 8, 8, 768)    0           ['conv2d_103[0][0]',
#                                                                   'concatenate_48[0][0]']
#
#  batch_normalization_103 (Batch  (None, 8, 8, 768)   3072        ['concatenate_49[0][0]']
#  Normalization)
#
#  re_lu_103 (ReLU)               (None, 8, 8, 768)    0           ['batch_normalization_103[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 8, 8, 128)    98432       ['re_lu_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 8, 8, 128)   512         ['conv2d_104[0][0]']
#  Normalization)
#
#  re_lu_104 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_104[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_104[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 8, 8, 800)    0           ['conv2d_105[0][0]',
#                                                                   'concatenate_49[0][0]']
#
#  batch_normalization_105 (Batch  (None, 8, 8, 800)   3200        ['concatenate_50[0][0]']
#  Normalization)
#
#  re_lu_105 (ReLU)               (None, 8, 8, 800)    0           ['batch_normalization_105[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 8, 8, 128)    102528      ['re_lu_105[0][0]']
#
#  batch_normalization_106 (Batch  (None, 8, 8, 128)   512         ['conv2d_106[0][0]']
#  Normalization)
#
#  re_lu_106 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_106[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_106[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 8, 8, 832)    0           ['conv2d_107[0][0]',
#                                                                   'concatenate_50[0][0]']
#
#  batch_normalization_107 (Batch  (None, 8, 8, 832)   3328        ['concatenate_51[0][0]']
#  Normalization)
#
#  re_lu_107 (ReLU)               (None, 8, 8, 832)    0           ['batch_normalization_107[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 8, 8, 128)    106624      ['re_lu_107[0][0]']
#
#  batch_normalization_108 (Batch  (None, 8, 8, 128)   512         ['conv2d_108[0][0]']
#  Normalization)
#
#  re_lu_108 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_108[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_108[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 8, 8, 864)    0           ['conv2d_109[0][0]',
#                                                                   'concatenate_51[0][0]']
#
#  batch_normalization_109 (Batch  (None, 8, 8, 864)   3456        ['concatenate_52[0][0]']
#  Normalization)
#
#  re_lu_109 (ReLU)               (None, 8, 8, 864)    0           ['batch_normalization_109[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 8, 8, 128)    110720      ['re_lu_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 8, 8, 128)   512         ['conv2d_110[0][0]']
#  Normalization)
#
#  re_lu_110 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_110[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_110[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 8, 8, 896)    0           ['conv2d_111[0][0]',
#                                                                   'concatenate_52[0][0]']
#
#  batch_normalization_111 (Batch  (None, 8, 8, 896)   3584        ['concatenate_53[0][0]']
#  Normalization)
#
#  re_lu_111 (ReLU)               (None, 8, 8, 896)    0           ['batch_normalization_111[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 8, 8, 128)    114816      ['re_lu_111[0][0]']
#
#  batch_normalization_112 (Batch  (None, 8, 8, 128)   512         ['conv2d_112[0][0]']
#  Normalization)
#
#  re_lu_112 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_112[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_112[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 8, 8, 928)    0           ['conv2d_113[0][0]',
#                                                                   'concatenate_53[0][0]']
#
#  batch_normalization_113 (Batch  (None, 8, 8, 928)   3712        ['concatenate_54[0][0]']
#  Normalization)
#
#  re_lu_113 (ReLU)               (None, 8, 8, 928)    0           ['batch_normalization_113[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 8, 8, 128)    118912      ['re_lu_113[0][0]']
#
#  batch_normalization_114 (Batch  (None, 8, 8, 128)   512         ['conv2d_114[0][0]']
#  Normalization)
#
#  re_lu_114 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_114[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_114[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 8, 8, 960)    0           ['conv2d_115[0][0]',
#                                                                   'concatenate_54[0][0]']
#
#  batch_normalization_115 (Batch  (None, 8, 8, 960)   3840        ['concatenate_55[0][0]']
#  Normalization)
#
#  re_lu_115 (ReLU)               (None, 8, 8, 960)    0           ['batch_normalization_115[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 8, 8, 128)    123008      ['re_lu_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 8, 8, 128)   512         ['conv2d_116[0][0]']
#  Normalization)
#
#  re_lu_116 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_116[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 8, 8, 992)    0           ['conv2d_117[0][0]',
#                                                                   'concatenate_55[0][0]']
#
#  batch_normalization_117 (Batch  (None, 8, 8, 992)   3968        ['concatenate_56[0][0]']
#  Normalization)
#
#  re_lu_117 (ReLU)               (None, 8, 8, 992)    0           ['batch_normalization_117[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 8, 8, 128)    127104      ['re_lu_117[0][0]']
#
#  batch_normalization_118 (Batch  (None, 8, 8, 128)   512         ['conv2d_118[0][0]']
#  Normalization)
#
#  re_lu_118 (ReLU)               (None, 8, 8, 128)    0           ['batch_normalization_118[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 8, 8, 32)     36896       ['re_lu_118[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 8, 8, 1024)   0           ['conv2d_119[0][0]',
#                                                                   'concatenate_56[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['concatenate_57[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 10)           10250       ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 7,053,642
# Trainable params: 6,972,170
# Non-trainable params: 81,472
# __________________________________________________________________________________________________

# %%
root_logdir = os.path.join(os.curdir, "logs\\fit\\")
def get_run_logdir():
    run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
    return os.path.join(root_logdir, run_id)
run_logdir = get_run_logdir()
tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)

# %%
model.compile(loss='sparse_categorical_crossentropy', optimizer=tf.optimizers.SGD(lr=0.001), metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history = model.fit(train_ds,
                    epochs=20,
                    validation_data=validation_ds,
                    validation_freq=1,
                    callbacks=[tensorboard_cb])
# Out:
# Epoch 1/20
# 46/46 [==============================] - 92s 969ms/step - loss: 2.2987 - accuracy: 0.1352 - val_loss: 2.2979 - val_accuracy: 0.1458
# Epoch 2/20
# 46/46 [==============================] - 43s 925ms/step - loss: 2.1733 - accuracy: 0.1861 - val_loss: 2.2973 - val_accuracy: 0.1396
# Epoch 3/20
# 46/46 [==============================] - 43s 929ms/step - loss: 2.1150 - accuracy: 0.2181 - val_loss: 2.2860 - val_accuracy: 0.1562
# Epoch 4/20
# 46/46 [==============================] - 43s 925ms/step - loss: 2.0547 - accuracy: 0.2493 - val_loss: 2.2536 - val_accuracy: 0.2062
# Epoch 5/20
# 46/46 [==============================] - 43s 926ms/step - loss: 2.0146 - accuracy: 0.2833 - val_loss: 2.1978 - val_accuracy: 0.2083
# Epoch 6/20
# 46/46 [==============================] - 43s 930ms/step - loss: 1.9806 - accuracy: 0.2894 - val_loss: 2.1424 - val_accuracy: 0.2083
# Epoch 7/20
# 46/46 [==============================] - 43s 932ms/step - loss: 1.9535 - accuracy: 0.3030 - val_loss: 2.0768 - val_accuracy: 0.2500
# Epoch 8/20
# 46/46 [==============================] - 43s 930ms/step - loss: 1.9333 - accuracy: 0.3118 - val_loss: 2.0183 - val_accuracy: 0.2542
# Epoch 9/20
# 46/46 [==============================] - 43s 930ms/step - loss: 1.9086 - accuracy: 0.3261 - val_loss: 1.9817 - val_accuracy: 0.3042
# Epoch 10/20
# 46/46 [==============================] - 43s 932ms/step - loss: 1.8807 - accuracy: 0.3349 - val_loss: 1.9406 - val_accuracy: 0.3167
# Epoch 11/20
# 46/46 [==============================] - 43s 931ms/step - loss: 1.8624 - accuracy: 0.3438 - val_loss: 1.9279 - val_accuracy: 0.2937
# Epoch 12/20
# 46/46 [==============================] - 43s 924ms/step - loss: 1.8462 - accuracy: 0.3458 - val_loss: 1.9316 - val_accuracy: 0.3000
# Epoch 13/20
# 46/46 [==============================] - 43s 922ms/step - loss: 1.8420 - accuracy: 0.3628 - val_loss: 1.9136 - val_accuracy: 0.3250
# Epoch 14/20
# 46/46 [==============================] - 43s 925ms/step - loss: 1.8268 - accuracy: 0.3614 - val_loss: 1.8857 - val_accuracy: 0.3104
# Epoch 15/20
# 46/46 [==============================] - 43s 932ms/step - loss: 1.8060 - accuracy: 0.3879 - val_loss: 1.8839 - val_accuracy: 0.3146
# Epoch 16/20
# 46/46 [==============================] - 43s 930ms/step - loss: 1.7890 - accuracy: 0.3791 - val_loss: 1.8944 - val_accuracy: 0.2958
# Epoch 17/20
# 46/46 [==============================] - 43s 928ms/step - loss: 1.7773 - accuracy: 0.3764 - val_loss: 1.8817 - val_accuracy: 0.3146
# Epoch 18/20
# 46/46 [==============================] - 43s 927ms/step - loss: 1.7701 - accuracy: 0.3607 - val_loss: 1.8695 - val_accuracy: 0.3396
# Epoch 19/20
# 46/46 [==============================] - 43s 934ms/step - loss: 1.7551 - accuracy: 0.3859 - val_loss: 1.8481 - val_accuracy: 0.3354
# Epoch 20/20
# 46/46 [==============================] - 43s 926ms/step - loss: 1.7492 - accuracy: 0.3974 - val_loss: 1.8649 - val_accuracy: 0.3208

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['loss'], label = 'loss')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()

plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('loss')
plt.ylim([0, 3])
plt.legend(loc='lower right')
plt.show()
